# %%
import numpy as np
import pandas as pd

# %%
rmsetrain1=np.load('rmse_train1.npy')
rmsetest1=np.load('rmse_test1.npy')

# %%
rmsetrain1
# Out:
# array([1.51772583, 1.41311136, 1.33134676, 1.26691682, 1.21562922,
#        1.17429861, 1.14052776, 1.11252781, 1.08896935, 1.06886395,
#        1.05147353, 1.03624303, 1.02275141, 1.01067615, 0.99976767,
#        0.98983091, 0.98071184, 0.97228763, 0.96445944, 0.95714695,
#        0.95028435, 0.94381723, 0.93770026, 0.93189537, 0.92637033,
#        0.92109766, 0.91605379, 0.91121836, 0.90657364, 0.90210414,
#        0.89779623, 0.89363785, 0.8896183 , 0.885728  , 0.88195836,
#        0.87830164, 0.87475084, 0.87129961, 0.86794215, 0.86467315,
#        0.86148777, 0.85838153, 0.85535031, 0.85239029, 0.84949794,
#        0.84666997, 0.84390333, 0.84119515, 0.83854278, 0.8359437 ,
#        0.83339559, 0.83089623, 0.82844355, 0.8260356 , 0.82367054,
#        0.82134662, 0.81906219, 0.81681571, 0.81460568, 0.81243071,
#        0.81028946, 0.80818067, 0.80610312, 0.80405568, 0.80203723,
#        0.80004675, 0.79808322, 0.7961457 , 0.79423328, 0.79234509,
# ...

# %%
rmsetest1
# Out:
# array([1.53399508, 1.43772089, 1.36354982, 1.30611443, 1.26133944,
#        1.22612662, 1.19814201, 1.17564272, 1.15733356, 1.14225254,
#        1.12968287, 1.11908741, 1.11006058, 1.10229351, 1.09554887,
#        1.08964252, 1.08443032, 1.07979836, 1.0756558 , 1.07192961,
#        1.06856051, 1.06550002, 1.06270818, 1.06015178, 1.05780302,
#        1.05563849, 1.0536383 , 1.05178547, 1.0500654 , 1.04846549,
#        1.04697476, 1.04558363, 1.04428368, 1.04306748, 1.04192844,
#        1.0408607 , 1.03985901, 1.03891866, 1.03803543, 1.03720547,
#        1.03642533, 1.03569184, 1.03500213, 1.03435357, 1.03374375,
#        1.03317046, 1.03263165, 1.03212545, 1.03165012, 1.03120404,
#        1.03078573, 1.0303938 , 1.03002695, 1.02968397, 1.02936375,
#        1.02906523, 1.02878743, 1.02852942, 1.02829034, 1.02806937,
#        1.02786575, 1.02767875, 1.02750771, 1.02735198, 1.02721095,
#        1.02708405, 1.02697075, 1.02687053, 1.02678292, 1.02670744,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(rmsetrain1, color='r')
plt.plot(rmsetest1, color='b')
plt.legend(['train','test'])
plt.show()

# %%
rmsetrain2=np.load('rmse_train2.npy')
rmsetest2=np.load('rmse_test2.npy')

# %%
rmsetrain2
# Out:
# array([1.50486073, 1.39991181, 1.31795407, 1.2533814 , 1.20197937,
#        1.16055966, 1.12672458, 1.09868348, 1.07510401, 1.0549944 ,
#        1.03761344, 1.0224035 , 1.0089415 , 0.99690341, 0.98603857,
#        0.97615113, 0.96708651, 0.95872147, 0.95095684, 0.94371206,
#        0.9369211 , 0.93052935, 0.92449129, 0.91876868, 0.9133291 ,
#        0.90814491, 0.90319237, 0.89845094, 0.89390274, 0.88953212,
#        0.88532529, 0.88127007, 0.87735559, 0.87357215, 0.86991103,
#        0.86636438, 0.86292508, 0.85958667, 0.85634325, 0.85318943,
#        0.85012027, 0.84713121, 0.84421806, 0.84137692, 0.83860419,
#        0.83589653, 0.83325083, 0.83066416, 0.82813382, 0.82565725,
#        0.82323208, 0.82085605, 0.81852706, 0.81624312, 0.81400236,
#        0.81180299, 0.80964336, 0.80752187, 0.80543702, 0.80338739,
#        0.80137162, 0.79938842, 0.79743658, 0.79551492, 0.79362234,
#        0.79175778, 0.78992023, 0.78810872, 0.78632233, 0.78456019,
# ...

# %%
rmsetest2
# Out:
# array([1.51909969, 1.42241175, 1.34795952, 1.29029203, 1.24531134,
#        1.20991389, 1.18176335, 1.15911411, 1.14066791, 1.12545983,
#        1.11277063, 1.10206135, 1.09292511, 1.08505223, 1.07820483,
#        1.0721985 , 1.06688894, 1.06216216, 1.05792729, 1.05411125,
#        1.05065475, 1.04750928, 1.04463483, 1.04199812, 1.03957132,
#        1.0373309 , 1.03525692, 1.03333231, 1.0315424 , 1.02987446,
#        1.02831746, 1.02686172, 1.02549873, 1.02422098, 1.02302181,
#        1.02189527, 1.02083606, 1.01983939, 1.01890096, 1.0180169 ,
#        1.01718366, 1.01639804, 1.01565712, 1.01495822, 1.01429888,
#        1.01367685, 1.01309006, 1.0125366 , 1.01201468, 1.01152267,
#        1.01105906, 1.01062242, 1.01021145, 1.00982491, 1.00946166,
#        1.00912064, 1.00880084, 1.00850133, 1.00822123, 1.00795971,
#        1.00771601, 1.00748939, 1.00727916, 1.00708469, 1.00690536,
#        1.00674061, 1.00658988, 1.00645267, 1.0063285 , 1.0062169 ,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(rmsetrain2, color='r')
plt.plot(rmsetest2, color='b')
plt.legend(['train','test'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(np.arange(1, len(rmsetrain1)+1), rmsetrain1, color='r')
plt.plot(np.arange(1, len(rmsetest1)+1), rmsetest1, color='y')
plt.plot(np.arange(1, len(rmsetrain2)+1), rmsetrain2, color='b')
plt.plot(np.arange(1, len(rmsetest2)+1), rmsetest2, color='g')
plt.suptitle('RMSE (α = 0,001)')
plt.xlabel('Step')
plt.ylabel('RMSE')
plt.legend(['LRtrain','LRtest','IBtrain','IBtest'])
plt.show()

# %%
len(rmsetrain1)
# Out:
# 77
